# %% [markdown]
# ++his is an assignment on Pandas and Matplotlib. These are important tools that will be used in upcoming assignments.

# %% [markdown]
# # Import Libraries
#
# We shall start by importing the Python libraries you will need to run the code.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib

# %matplotlib inline

# %% [markdown]
# [Pandas](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html) and [matplotlib](https://www.tutorialspoint.com/numpy/numpy_matplotlib.htm) go through these tutorials before you start doing the assignment.

# %% [markdown]
# ## Load the Data
# ### About the data
#
# The U.S. Census Bureau began asking internet use in American Community Survey (ACS) in 2013, as part of the 2008 Broadband Data Improvement Act, and has published 1-year estimate each year since 2013. The recent 2016 data shows that in many counties, over a quarter of household still do not have internet access.

# %%
#Here we load the data
df = pd.read_csv("kaggle_internet.csv")
print('shape of the data:'+str(df.shape))
df.head()
# Out:
# shape of the data:(820, 23)
#                          county state         GEOID         lon        lat  \
# 0        Anchorage Municipality    AK  05000US02020 -149.274354  61.177549
# 1  Fairbanks North Star Borough    AK  05000US02090 -146.599867  64.690832
# 2     Matanuska-Susitna Borough    AK  05000US02170 -149.407974  62.182173
# 3                Baldwin County    AL  05000US01003  -87.746067  30.659218
# 4                Calhoun County    AL  05000US01015  -85.822513  33.771706
#
#    P_total   P_white  P_black  P_asian  P_native  ...  P_some_high_school  \
# 0   298192  184841.0  16102.0  27142.0   23916.0  ...              8196.0
# 1   100605   75501.0   4385.0   3875.0    7427.0  ...              1527.0
# 2   104365   86314.0   1019.0   1083.0    5455.0  ...              2755.0
# 3   208563  180484.0  18821.0    914.0    1383.0  ...             10506.0
# 4   114611       NaN      NaN      NaN       NaN  ...              8853.0
#
#    P_high_school_equivalent  P_some_college  P_bachelor_and_above  \
# 0                   44804.0         66162.0               70713.0
# 1                   14725.0         24570.0               19257.0
# 2                   21071.0         28472.0               12841.0
# 3                   41822.0         46790.0               43547.0
# 4                   24761.0         26625.0               12909.0
#
#    P_below_poverty  median_age  gini_index  median_household_income  \
# 0            18302        33.0      0.4018                    85634
# 1             9580        30.6      0.3756                    77328
# 2             9893        34.2      0.4351                    69332
# 3            23375        42.4      0.4498                    56732
# 4            18193        39.1      0.4692                    41687
#
#    median_rent_per_income  percent_no_internet
# 0                    28.0             6.593887
# 1                    25.6            12.102458
# 2                    29.6            11.156575
# 3                    29.3            17.868167
# 4                    24.8            23.464932
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Working with the data

# %% [markdown]
# ### 1.1 Check the correlation between the column using correlation matrix

# %%
#let's write the code for correlation matix
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col1 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col2 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col3 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col4 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col10 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col11 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col12 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col13 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col14 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col15 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col16 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col17 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col18 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow0_col19 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col0 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col2 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col3 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col5 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col6 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col7 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col8 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col9 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col11 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col12 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col13 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col14 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col15 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col16 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col17 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col18 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow1_col19 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col0 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col1 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col3 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col4 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col5 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col6 {
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col7 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col8 {
#             background-color:  #de614d;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col9 {
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col10 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col11 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col12 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col13 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col14 {
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col15 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col16 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col17 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col18 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_a94af554_83d5_11e9_847d_40a3cced84fbrow2_col19 {
#             background-color:  #a6c4fe;

# %% [markdown]
# ### Correlation
# Correlation is a statistical measure that indicates the extent to which two or more variables fluctuate together. A positive correlation indicates the extent to which those variables increase or decrease in parallel; a negative correlation indicates the extent to which one variable increases as the other decreases.
# Check out this [blog](https://www.datascience.com/learn-data-science/fundamentals/introduction-to-correlation-python-data-science) have a good mathematical explanation of correlation and here are the [types](http://benalexkeen.com/correlation-in-python/) of it.

# %% [markdown]
# ### Drop unncessary columns
# Here some columns have high similarity just like correlation between P_white and P_total is 0.9719 so can remove P_white, it won't affect the information extracted from the data.Generally, we do this if we have unncessary columns especially if the dimensions are very high, for example there are 1500 columns. We do this to decrease the computation cost.

# %%
#Using the correlation scores make a list of columns to drop and drop the columns.
drop_list= ['P_white','P_some_high_school','P_some_college','P_high_school_equivalent','P_bachelor_and_above','P_below_poverty','P_below_middle_school']
#Begin the code
df = df.drop(columns=drop_list)
#End the code

# %% [markdown]
# ## 2.0 Plot the data
#
# After loading the data and removing unnecessary columns now we are going to visualize the data by scatter plot, line plot, histogram plot and few more using [matplotlib](https://www.tutorialspoint.com/numpy/numpy_matplotlib.htm) library.
# We will define functions for each plot to make our code re-usable.

# %% [markdown]
# But before plotting, you must set some parameters common to all the plots. This is done in order to make the visibility and readability of the plots better. This can be done by changing the default rc settings defined in the matplotlibrc configuration files. One example is given.

# %%
#Set plot size to 14" x 7" (Solved Example)
matplotlib.rc('figure', figsize = (14, 7))

#Set the font size to 15


#Do not display the top and right frame lines

matplotlib.rcParams.update({'font.size': 15,'axes.spines.right' : False,'axes.spines.top' : False})

#You can try experimenting with the background color, grid lines and font style

# %% [markdown]
# ## 2.1 Scatter Plot
#
# This is the most used plot for gaining insight into data while dealing with Machine Learning problems. For your convenience, the code for scatter plot is given as an example.

# %%
def scatter_plot(x_data, y_data, x_label, y_label, title):
    
    plt.scatter(x_data, y_data, s = 15, color = '#539caf', alpha = 0.75)
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    
    
scatter_plot(x_data = df['lat']
            , y_data = df['lon'] 
            , x_label = 'lat'
            , y_label = 'lon'
            , title = 'lon vs lat')

# %% [markdown]
# ## 2.2 Histogram

# %% [markdown]
# Now here your task is to complete this histogram function

# %%
#Fill the function given below
def histogram(data, x_label, y_label, title):
#Begin the code
    plt.hist(data)
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)



#End the code    
#Calling the function "histogram"
histogram(data = df['percent_no_internet']
           , x_label = '%_no_internet'
           , y_label = 'Frequency'
           , title = 'Distribution of percent of household without internet connection')

# %% [markdown]
# ## 2.3 Line plot

# %% [markdown]
# Import the data for line plot.

# %%
df2=pd.read_csv('day.csv')
df2.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# Similarly complete the lineplot function

# %%
#Fill the function given below
def lineplot(x_data, y_data, x_label, y_label, title):
#Begin the code

    plt.plot(x_data, y_data)
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)




#End the code    
#Calling the function to create plot
lineplot(x_data = df2['dteday']
         , y_data = df2['cnt']
         , x_label = 'Date'
         , y_label = 'Total Checkouts'
         , title = 'Total Checkouts for Each Day')

# %% [markdown]
# ## 2.4 Subplots

# %% [markdown]
# The Matplotlib subplot() function can be called to plot two or more plots in one figure. Matplotlib supports all kind of subplots including 2x1 vertical, 2x1 horizontal or a 2x2 grid.
# Sometimes there is a need to plot subplot. Here, for example, we plot histogram and scatter plot together.

# %%
plt.subplot(211)
scatter_plot(x_data = df['lat']
            , y_data = df['lon'] 
            , x_label = 'lat'
            , y_label = 'lon'
            , title = 'lon vs lat')
plt.subplot(212)
histogram(data = df['percent_no_internet']
           , x_label = '%_no_internet'
           , y_label = 'Frequency'
           , title = 'Distribution of percent of household without internet connection')

# %% [markdown]
# Here, your task is to write the code for subplot having two line plots.

# %%
#Complete the function
def line_2subplot(x1_data, x1_label, y1_data, y1_label,title1, x2_data, x2_label, y2_data, y2_label,title2):
#Begin the code
    plt.subplot(211)
    lineplot(x_data = x1_data
                , y_data = y1_data 
                , x_label = x1_label
                , y_label = y1_label
                , title = title1)
    plt.subplot(212)
    lineplot(x_data = x2_data
                , y_data = y2_data 
                , x_label = x2_label
                , y_label = y2_label
                , title = title2)



#End the code        
#Calling the function to create subplot
line_2subplot(x1_data = df2['dteday']
              ,x1_label = 'Date',y1_data = df2['casual']
              , y1_label = 'Casual Checkouts'
              ,title1 = 'Total Casual Checkouts for Each Day'
              ,x2_data = df2['dteday'] ,x2_label = 'Date',y2_data = df2['registered']
              ,y2_label = 'Registered Checkouts'
              ,title2 = 'Total Registered Checkouts for Each Day')

# %% [markdown]
# ## 2.5 Comparing Two Line Plots
#
# This is useful for comparing two variables over a third variable. It must be noted that these variables may have different scales (they do in the example given below).

# %%
#Fill the function given below
def lineplot2y(x_data, x_label, y1_data, y1_label, y2_data, y2_label, title):
#Begin the code
    fig, ax1 = plt.subplots()

    color = 'tab:red'
    ax1.set_xlabel(x_label)
    ax1.set_ylabel(y1_label, color=color)
    ax1.plot(x_data, y1_data, color=color)
    ax1.tick_params(axis='y', labelcolor=color)

    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

    color = 'tab:blue'
    ax2.set_ylabel(y2_label, color=color)  # we already handled the x-label with ax1
    ax2.plot(x_data, y2_data, color=color)
    ax2.tick_params(axis='y', labelcolor=color)

    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    plt.show()





#End the code       
#Calling the function to create plot
lineplot2y(x_data = df2['dteday']
           , x_label = 'Date'
           , y1_data = df2['casual']
           , y1_label = 'Casual Checkouts'
           , y2_data = df2['registered']
           , y2_label = 'Registered Checkouts'
           , title = 'No. of Registered vs Casual Checkouts for Each Day')

# %% [markdown]
# # It's Finished
# Congratulations! you have completed your first assignment.There are lots of plots you can explore, these plots will help you to visualize data in your upcoming assignment.You can also perform numpy operations on the given data.

# %% [markdown]
# PS:You need to submit this Python notebook for this part of the assignment.
