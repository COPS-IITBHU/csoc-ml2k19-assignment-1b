# %% [markdown]
# This is an assignment on Pandas and Matplotlib. These are important tools that will be used in upcoming assignments.

# %% [markdown]
# # Import Libraries
#
# We shall start by importing the Python libraries you will need to run the code.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib

# %matplotlib inline

# %% [markdown]
# [Pandas](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html) and [matplotlib](https://www.tutorialspoint.com/numpy/numpy_matplotlib.htm) go through these tutorials before you start doing the assignment.

# %% [markdown]
# ## Load the Data
# ### About the data
#
# The U.S. Census Bureau began asking internet use in American Community Survey (ACS) in 2013, as part of the 2008 Broadband Data Improvement Act, and has published 1-year estimate each year since 2013. The recent 2016 data shows that in many counties, over a quarter of household still do not have internet access.

# %%
#Here we load the data
df = pd.read_csv("kaggle_internet.csv")
print('shape of the data:'+str(df.shape))
df.head()
# Out:
# shape of the data:(820, 23)
#                          county state         GEOID         lon        lat  \
# 0        Anchorage Municipality    AK  05000US02020 -149.274354  61.177549
# 1  Fairbanks North Star Borough    AK  05000US02090 -146.599867  64.690832
# 2     Matanuska-Susitna Borough    AK  05000US02170 -149.407974  62.182173
# 3                Baldwin County    AL  05000US01003  -87.746067  30.659218
# 4                Calhoun County    AL  05000US01015  -85.822513  33.771706
#
#    P_total   P_white  P_black  P_asian  P_native  ...  P_some_high_school  \
# 0   298192  184841.0  16102.0  27142.0   23916.0  ...              8196.0
# 1   100605   75501.0   4385.0   3875.0    7427.0  ...              1527.0
# 2   104365   86314.0   1019.0   1083.0    5455.0  ...              2755.0
# 3   208563  180484.0  18821.0    914.0    1383.0  ...             10506.0
# 4   114611       NaN      NaN      NaN       NaN  ...              8853.0
#
#    P_high_school_equivalent  P_some_college  P_bachelor_and_above  \
# 0                   44804.0         66162.0               70713.0
# 1                   14725.0         24570.0               19257.0
# 2                   21071.0         28472.0               12841.0
# 3                   41822.0         46790.0               43547.0
# 4                   24761.0         26625.0               12909.0
#
#    P_below_poverty  median_age  gini_index  median_household_income  \
# 0            18302        33.0      0.4018                    85634
# 1             9580        30.6      0.3756                    77328
# 2             9893        34.2      0.4351                    69332
# 3            23375        42.4      0.4498                    56732
# 4            18193        39.1      0.4692                    41687
#
#    median_rent_per_income  percent_no_internet
# 0                    28.0             6.593887
# 1                    25.6            12.102458
# 2                    29.6            11.156575
# 3                    29.3            17.868167
# 4                    24.8            23.464932
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Working with the data

# %% [markdown]
# ### 1.1 Check the correlation between the column using correlation matrix

# %%
#let's write the code for correlation matix
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
print(corr)
# Out:
#                                lon       lat   P_total   P_white   P_black  \
# lon                       1.000000 -0.054320 -0.104168 -0.068606  0.132779
# lat                      -0.054320  1.000000 -0.081087 -0.115944 -0.157080
# P_total                  -0.104168 -0.081087  1.000000  0.971922  0.747189
# P_white                  -0.068606 -0.115944  0.971922  1.000000  0.664573
# P_black                   0.132779 -0.157080  0.747189  0.664573  1.000000
# P_asian                  -0.168883 -0.071740  0.838708  0.745596  0.498853
# P_native                 -0.280450 -0.067080  0.521726  0.518515  0.254333
# P_hawaiian               -0.375879 -0.165592  0.340207  0.289749  0.109936
# P_others                 -0.124056 -0.071789  0.855374  0.763149  0.530272
# P_below_middle_school    -0.137603 -0.105721  0.911578  0.844091  0.607151
# P_some_high_school       -0.096755 -0.126938  0.966224  0.914558  0.747170
# P_high_school_equivalent -0.047241 -0.089206  0.977597  0.951750  0.781068
# P_some_college           -0.146114 -0.089257  0.988319  0.974050  0.714326
# P_bachelor_and_above     -0.075354 -0.036896  0.961460  0.935758  0.711801
# P_below_poverty          -0.099790 -0.117663  0.962629  0.913047  0.786508
# median_age                0.243585  0.009124 -0.115311 -0.053713 -0.135321
# gini_index                0.006900 -0.220039  0.225810  0.231168  0.367019
# median_household_income   0.000627  0.215803  0.172653  0.162942 -0.020654
# median_rent_per_income   -0.060051 -0.158108  0.155607  0.151586  0.163333
# percent_no_internet       0.076285 -0.233225 -0.153540 -0.144966  0.040852
#
#                            P_asian  P_native  P_hawaiian  P_others  \
# lon                      -0.168883 -0.280450   -0.375879 -0.124056
# lat                      -0.071740 -0.067080   -0.165592 -0.071789
# P_total                   0.838708  0.521726    0.340207  0.855374
# P_white                   0.745596  0.518515    0.289749  0.763149
# P_black                   0.498853  0.254333    0.109936  0.530272
# P_asian                   1.000000  0.415273    0.490670  0.820922
# P_native                  0.415273  1.000000    0.208973  0.507351
# P_hawaiian                0.490670  0.208973    1.000000  0.295154
# P_others                  0.820922  0.507351    0.295154  1.000000
# P_below_middle_school     0.847392  0.498016    0.309052  0.958529
# P_some_high_school        0.801515  0.523581    0.304417  0.900865
# P_high_school_equivalent  0.770177  0.491458    0.318295  0.818371
# P_some_college            0.803109  0.550494    0.364193  0.833609
# P_bachelor_and_above      0.856748  0.459467    0.324723  0.770893
# P_below_poverty           0.767018  0.529864    0.288917  0.870034
# median_age               -0.071212 -0.135888   -0.048245 -0.092994
# gini_index                0.154280  0.116599    0.009217  0.152059
# median_household_income   0.250282 -0.069212    0.120942  0.054178
# median_rent_per_income    0.118461 -0.016019    0.098766  0.147329
# percent_no_internet      -0.144779  0.210119   -0.089141 -0.022089
#
#                           P_below_middle_school  P_some_high_school  \
# lon                                   -0.137603           -0.096755
# lat                                   -0.105721           -0.126938
# P_total                                0.911578            0.966224
# P_white                                0.844091            0.914558
# P_black                                0.607151            0.747170
# P_asian                                0.847392            0.801515
# P_native                               0.498016            0.523581
# P_hawaiian                             0.309052            0.304417
# P_others                               0.958529            0.900865
# P_below_middle_school                  1.000000            0.951299
# P_some_high_school                     0.951299            1.000000
# P_high_school_equivalent               0.877369            0.964380
# P_some_college                         0.884949            0.953783
# P_bachelor_and_above                   0.829607            0.876091
# P_below_poverty                        0.925874            0.985925
# median_age                            -0.112191           -0.113842
# gini_index                             0.180362            0.235161
# median_household_income                0.068927            0.034595
# median_rent_per_income                 0.154153            0.174466
# percent_no_internet                   -0.040920           -0.035365
#
#                           P_high_school_equivalent  P_some_college  \
# lon                                      -0.047241       -0.146114
# lat                                      -0.089206       -0.089257
# P_total                                   0.977597        0.988319
# P_white                                   0.951750        0.974050
# P_black                                   0.781068        0.714326
# P_asian                                   0.770177        0.803109
# P_native                                  0.491458        0.550494
# P_hawaiian                                0.318295        0.364193
# P_others                                  0.818371        0.833609
# P_below_middle_school                     0.877369        0.884949
# P_some_high_school                        0.964380        0.953783
# P_high_school_equivalent                  1.000000        0.972852
# P_some_college                            0.972852        1.000000
# P_bachelor_and_above                      0.909635        0.932253
# P_below_poverty                           0.958011        0.948114
# median_age                               -0.065336       -0.097632
# gini_index                                0.220578        0.198178
# median_household_income                   0.106220        0.147486
# median_rent_per_income                    0.167545        0.158772
# percent_no_internet                      -0.101170       -0.161114
#
#                           P_bachelor_and_above  P_below_poverty  median_age  \
# lon                                  -0.075354        -0.099790    0.243585
# lat                                  -0.036896        -0.117663    0.009124
# P_total                               0.961460         0.962629   -0.115311
# P_white                               0.935758         0.913047   -0.053713
# P_black                               0.711801         0.786508   -0.135321
# P_asian                               0.856748         0.767018   -0.071212
# P_native                              0.459467         0.529864   -0.135888
# P_hawaiian                            0.324723         0.288917   -0.048245
# P_others                              0.770893         0.870034   -0.092994
# P_below_middle_school                 0.829607         0.925874   -0.112191
# P_some_high_school                    0.876091         0.985925   -0.113842
# P_high_school_equivalent              0.909635         0.958011   -0.065336
# P_some_college                        0.932253         0.948114   -0.097632
# P_bachelor_and_above                  1.000000         0.879987   -0.095776
# P_below_poverty                       0.879987         1.000000   -0.155761
# median_age                           -0.095776        -0.155761    1.000000
# gini_index                            0.247607         0.288348   -0.111163
# median_household_income               0.297704         0.005033    0.046581
# median_rent_per_income                0.123530         0.194196   -0.074066
# percent_no_internet                  -0.236293        -0.026435    0.068768
#
#                           gini_index  median_household_income  \
# lon                         0.006900                 0.000627
# lat                        -0.220039                 0.215803
# P_total                     0.225810                 0.172653
# P_white                     0.231168                 0.162942
# P_black                     0.367019                -0.020654
# P_asian                     0.154280                 0.250282
# P_native                    0.116599                -0.069212
# P_hawaiian                  0.009217                 0.120942
# P_others                    0.152059                 0.054178
# P_below_middle_school       0.180362                 0.068927
# P_some_high_school          0.235161                 0.034595
# P_high_school_equivalent    0.220578                 0.106220
# P_some_college              0.198178                 0.147486
# P_bachelor_and_above        0.247607                 0.297704
# P_below_poverty             0.288348                 0.005033
# median_age                 -0.111163                 0.046581
# gini_index                  1.000000                -0.303785
# median_household_income    -0.303785                 1.000000
# median_rent_per_income      0.391592                -0.135389
# percent_no_internet         0.240102                -0.706793
#
#                           median_rent_per_income  percent_no_internet
# lon                                    -0.060051             0.076285
# lat                                    -0.158108            -0.233225
# P_total                                 0.155607            -0.153540
# P_white                                 0.151586            -0.144966
# P_black                                 0.163333             0.040852
# P_asian                                 0.118461            -0.144779
# P_native                               -0.016019             0.210119
# P_hawaiian                              0.098766            -0.089141
# P_others                                0.147329            -0.022089
# P_below_middle_school                   0.154153            -0.040920
# P_some_high_school                      0.174466            -0.035365
# P_high_school_equivalent                0.167545            -0.101170
# P_some_college                          0.158772            -0.161114
# P_bachelor_and_above                    0.123530            -0.236293
# P_below_poverty                         0.194196            -0.026435
# median_age                             -0.074066             0.068768
# gini_index                              0.391592             0.240102
# median_household_income                -0.135389            -0.706793
# median_rent_per_income                  1.000000            -0.022836
# percent_no_internet                    -0.022836             1.000000

# %% [markdown]
# ### Correlation
# Correlation is a statistical measure that indicates the extent to which two or more variables fluctuate together. A positive correlation indicates the extent to which those variables increase or decrease in parallel; a negative correlation indicates the extent to which one variable increases as the other decreases.
# Check out this [blog](https://www.datascience.com/learn-data-science/fundamentals/introduction-to-correlation-python-data-science) have a good mathematical explanation of correlation and here are the [types](http://benalexkeen.com/correlation-in-python/) of it.

# %% [markdown]
# ### Drop unncessary columns
# Here some columns have high similarity just like correlation between P_white and P_total is 0.9719 so can remove P_white, it won't affect the information extracted from the data.Generally, we do this if we have unncessary columns especially if the dimensions are very high, for example there are 1500 columns. We do this to decrease the computation cost.

# %%
#Using the correlation scores make a list of columns to drop and drop the columns.
drop_list=['P_white','lat','lon','P_others']
#Begin the code
df.drop(drop_list,axis=1).corr()

#End the code
# Out:
#                            P_total   P_black   P_asian  P_native  P_hawaiian  \
# P_total                   1.000000  0.747189  0.838708  0.521726    0.340207
# P_black                   0.747189  1.000000  0.498853  0.254333    0.109936
# P_asian                   0.838708  0.498853  1.000000  0.415273    0.490670
# P_native                  0.521726  0.254333  0.415273  1.000000    0.208973
# P_hawaiian                0.340207  0.109936  0.490670  0.208973    1.000000
# P_below_middle_school     0.911578  0.607151  0.847392  0.498016    0.309052
# P_some_high_school        0.966224  0.747170  0.801515  0.523581    0.304417
# P_high_school_equivalent  0.977597  0.781068  0.770177  0.491458    0.318295
# P_some_college            0.988319  0.714326  0.803109  0.550494    0.364193
# P_bachelor_and_above      0.961460  0.711801  0.856748  0.459467    0.324723
# P_below_poverty           0.962629  0.786508  0.767018  0.529864    0.288917
# median_age               -0.115311 -0.135321 -0.071212 -0.135888   -0.048245
# gini_index                0.225810  0.367019  0.154280  0.116599    0.009217
# median_household_income   0.172653 -0.020654  0.250282 -0.069212    0.120942
# median_rent_per_income    0.155607  0.163333  0.118461 -0.016019    0.098766
# percent_no_internet      -0.153540  0.040852 -0.144779  0.210119   -0.089141
#
#                           P_below_middle_school  P_some_high_school  \
# P_total                                0.911578            0.966224
# P_black                                0.607151            0.747170
# P_asian                                0.847392            0.801515
# P_native                               0.498016            0.523581
# P_hawaiian                             0.309052            0.304417
# P_below_middle_school                  1.000000            0.951299
# P_some_high_school                     0.951299            1.000000
# P_high_school_equivalent               0.877369            0.964380
# P_some_college                         0.884949            0.953783
# P_bachelor_and_above                   0.829607            0.876091
# P_below_poverty                        0.925874            0.985925
# median_age                            -0.112191           -0.113842
# gini_index                             0.180362            0.235161
# median_household_income                0.068927            0.034595
# median_rent_per_income                 0.154153            0.174466
# percent_no_internet                   -0.040920           -0.035365
#
#                           P_high_school_equivalent  P_some_college  \
# P_total                                   0.977597        0.988319
# P_black                                   0.781068        0.714326
# P_asian                                   0.770177        0.803109
# P_native                                  0.491458        0.550494
# P_hawaiian                                0.318295        0.364193
# P_below_middle_school                     0.877369        0.884949
# P_some_high_school                        0.964380        0.953783
# P_high_school_equivalent                  1.000000        0.972852
# P_some_college                            0.972852        1.000000
# P_bachelor_and_above                      0.909635        0.932253
# P_below_poverty                           0.958011        0.948114
# median_age                               -0.065336       -0.097632
# gini_index                                0.220578        0.198178
# median_household_income                   0.106220        0.147486
# median_rent_per_income                    0.167545        0.158772
# percent_no_internet                      -0.101170       -0.161114
#
#                           P_bachelor_and_above  P_below_poverty  median_age  \
# P_total                               0.961460         0.962629   -0.115311
# P_black                               0.711801         0.786508   -0.135321
# P_asian                               0.856748         0.767018   -0.071212
# P_native                              0.459467         0.529864   -0.135888
# P_hawaiian                            0.324723         0.288917   -0.048245
# P_below_middle_school                 0.829607         0.925874   -0.112191
# P_some_high_school                    0.876091         0.985925   -0.113842
# P_high_school_equivalent              0.909635         0.958011   -0.065336
# P_some_college                        0.932253         0.948114   -0.097632
# P_bachelor_and_above                  1.000000         0.879987   -0.095776
# P_below_poverty                       0.879987         1.000000   -0.155761
# median_age                           -0.095776        -0.155761    1.000000
# gini_index                            0.247607         0.288348   -0.111163
# median_household_income               0.297704         0.005033    0.046581
# median_rent_per_income                0.123530         0.194196   -0.074066
# percent_no_internet                  -0.236293        -0.026435    0.068768
#
#                           gini_index  median_household_income  \
# P_total                     0.225810                 0.172653
# P_black                     0.367019                -0.020654
# P_asian                     0.154280                 0.250282
# P_native                    0.116599                -0.069212
# P_hawaiian                  0.009217                 0.120942
# P_below_middle_school       0.180362                 0.068927
# P_some_high_school          0.235161                 0.034595
# P_high_school_equivalent    0.220578                 0.106220
# P_some_college              0.198178                 0.147486
# P_bachelor_and_above        0.247607                 0.297704
# P_below_poverty             0.288348                 0.005033
# median_age                 -0.111163                 0.046581
# gini_index                  1.000000                -0.303785
# median_household_income    -0.303785                 1.000000
# median_rent_per_income      0.391592                -0.135389
# percent_no_internet         0.240102                -0.706793
#
#                           median_rent_per_income  percent_no_internet
# P_total                                 0.155607            -0.153540
# P_black                                 0.163333             0.040852
# P_asian                                 0.118461            -0.144779
# P_native                               -0.016019             0.210119
# P_hawaiian                              0.098766            -0.089141
# P_below_middle_school                   0.154153            -0.040920
# P_some_high_school                      0.174466            -0.035365
# P_high_school_equivalent                0.167545            -0.101170
# P_some_college                          0.158772            -0.161114
# P_bachelor_and_above                    0.123530            -0.236293
# P_below_poverty                         0.194196            -0.026435
# median_age                             -0.074066             0.068768
# gini_index                              0.391592             0.240102
# median_household_income                -0.135389            -0.706793
# median_rent_per_income                  1.000000            -0.022836
# percent_no_internet                    -0.022836             1.000000

# %% [markdown]
# ## 2.0 Plot the data
#
# After loading the data and removing unnecessary columns now we are going to visualize the data by scatter plot, line plot, histogram plot and few more using [matplotlib](https://www.tutorialspoint.com/numpy/numpy_matplotlib.htm) library.
# We will define functions for each plot to make our code re-usable.

# %% [markdown]
# But before plotting, you must set some parameters common to all the plots. This is done in order to make the visibility and readability of the plots better. This can be done by changing the default rc settings defined in the matplotlibrc configuration files. One example is given.

# %%
#Set plot size to 14" x 7" (Solved Example)
import numpy as np
##matplotlib.rc('figure', figsize = (14, 7))

#Set the font size to 15
matplotlib.rcParams.update({'font.size':15})

#Do not display the top and right frame lines
x=[1,3,4,5,6]
y=[2,1,1,5,5]
plt.xlabel('x axis')
plt.ylabel('y axis')
##fig, (graph) = plt.subplots(nrows=1)
#graph.set_facecolor('#eafff5')
#graph.plot(x,y)
#graph.spines['right'].set_visible(False)
#graph.spines['top'].set_visible(False)
#graph.yaxis.set_ticks_position('left')
#graph.xaxis.set_ticks_position('bottom')
#plt.grid(axis='both')
##plt.show()

plt.hist([x,y])
plt.show()
#You can try experimenting with the background color, grid lines and font style

# %% [markdown]
# ## 2.1 Scatter Plot
#
# This is the most used plot for gaining insight into data while dealing with Machine Learning problems. For your convenience, the code for scatter plot is given as an example.

# %%
def scatter_plot(x_data, y_data, x_label, y_label, title):
    
    plt.scatter(x_data, y_data, s = 15, color = '#539caf', alpha = 0.75)
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    
    
scatter_plot(x_data = df['lat']
            , y_data = df['lon'] 
            , x_label = 'lat'
            , y_label = 'lon'
            , title = 'lon vs lat')

# %% [markdown]
# ## 2.2 Histogram

# %% [markdown]
# Now here your task is to complete this histogram function

# %%
#Fill the function given below
def histogram(data, x_label, y_label, title):
#Begin the code
    plt.hist(data,bins=20)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.show()

#End the code    
#Calling the function "histogram"
histogram(data = df['percent_no_internet']
           , x_label = '%_no_internet'
           , y_label = 'Frequency'
           , title = 'Distribution of percent of household without internet connection')

# %% [markdown]
# ## 2.3 Line plot

# %% [markdown]
# Import the data for line plot.

# %%
df2=pd.read_csv('day.csv')
df2.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# Similarly complete the lineplot function

# %%
#Fill the function given below
def lineplot(x_data, y_data, x_label, y_label, title):
#Begin the code
    plt.plot(x_data,y_data)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.show()


#End the code    
#Calling the function to create plot
lineplot(x_data = df2['dteday']
         , y_data = df2['cnt']
         , x_label = 'Date'
         , y_label = 'Total Checkouts'
         , title = 'Total Checkouts for Each Day')

# %% [markdown]
# ## 2.4 Subplots

# %% [markdown]
# The Matplotlib subplot() function can be called to plot two or more plots in one figure. Matplotlib supports all kind of subplots including 2x1 vertical, 2x1 horizontal or a 2x2 grid.
# Sometimes there is a need to plot subplot. Here, for example, we plot histogram and scatter plot together.

# %%
plt.subplot(211)
scatter_plot(x_data = df['lat']
            , y_data = df['lon'] 
            , x_label = 'lat'
            , y_label = 'lon'
            , title = 'lon vs lat')
plt.subplot(212)
histogram(data = df['percent_no_internet']
           , x_label = '%_no_internet'
           , y_label = 'Frequency'
           , title = 'Distribution of percent of household without internet connection')

# %% [markdown]
# Here, your task is to write the code for subplot having two line plots.

# %%
#Complete the function
def line_2subplot(x1_data, x1_label, y1_data, y1_label,title1, x2_data, x2_label, y2_data, y2_label,title2):
#Begin the code
   
                             
   plt.subplot(211)
   lineplot(x1_data, y1_data, x1_label, y1_label, title1)

   plt.subplot(212)
   lineplot(x2_data, y2_data, x2_label, y2_label, title2)
#End the code        
#Calling the function to create subplot
line_2subplot(x1_data = df2['dteday']
              ,x1_label = 'Date',y1_data = df2['casual']
              , y1_label = 'Casual Checkouts'
              ,title1 = 'Total Casual Checkouts for Each Day'
              ,x2_data = df2['dteday'] ,x2_label = 'Date',y2_data = df2['registered']
              ,y2_label = 'Registered Checkouts'
              ,title2 = 'Total Registered Checkouts for Each Day')

# %% [markdown]
# ## 2.5 Comparing Two Line Plots
#
# This is useful for comparing two variables over a third variable. It must be noted that these variables may have different scales (they do in the example given below).

# %%
#Fill the function given below
def lineplot2y(x_data, x_label, y1_data, y1_label, y2_data, y2_label, title):
#Begin the code
    plt.plot(x_data,y1_data,'b-',x_data,y2_data,'r-')
    plt.title(title)
    plt.xlabel(x_label)
    plt.legend([y1_label,y2_label])
    plt.show()
#End the code       
#Calling the function to create plot
lineplot2y(x_data = df2['dteday']
           , x_label = 'Date'
           , y1_data = df2['casual']
           , y1_label = 'Casual Checkouts'
           , y2_data = df2['registered']
           , y2_label = 'Registered Checkouts'
           , title = 'No. of Registered vs Casual Checkouts for Each Day')

# %% [markdown]
# # It's Finished
# Congratulations! you have completed your first assignment.There are lots of plots you can explore, these plots will help you to visualize data in your upcoming assignment.You can also perform numpy operations on the given data.

# %% [markdown]
# PS:You need to submit this Python notebook for this part of the assignment.
